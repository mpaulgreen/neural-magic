# %% [markdown]
# # Train the model using CLI

# %%
# !pip install sparseml
# !pip install sparseml[transformers]
# Out:
# Collecting sparseml
#   Using cached sparseml-1.6.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: sparsezoo~=1.6.0 in /opt/conda/lib/python3.10/site-packages (from sparseml) (1.6.1)
# Requirement already satisfied: setuptools<=59.5.0 in /opt/conda/lib/python3.10/site-packages (from sparseml) (59.5.0)
# Requirement already satisfied: jupyter>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from sparseml) (1.0.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in /opt/conda/lib/python3.10/site-packages (from sparseml) (8.1.1)
# Requirement already satisfied: pyyaml>=5.0.0 in /opt/conda/lib/python3.10/site-packages (from sparseml) (6.0.1)
# Requirement already satisfied: progressbar2>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from sparseml) (4.3.2)
# Requirement already satisfied: numpy>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from sparseml) (1.25.2)
# Requirement already satisfied: matplotlib>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from sparseml) (3.7.3)
# Requirement already satisfied: merge-args>=0.1.0 in /opt/conda/lib/python3.10/site-packages (from sparseml) (0.1.5)
# Requirement already satisfied: onnx<1.15.0,>=1.5.0 in /opt/conda/lib/python3.10/site-packages (from sparseml) (1.14.1)
# Requirement already satisfied: pandas>=0.25.0 in /opt/conda/lib/python3.10/site-packages (from sparseml) (2.0.3)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from sparseml) (23.2)
# Requirement already satisfied: psutil>=5.0.0 in /opt/conda/lib/python3.10/site-packages (from sparseml) (5.9.3)
# Requirement already satisfied: pydantic<2.0.0,>=1.8.2 in /opt/conda/lib/python3.10/site-packages (from sparseml) (1.10.13)
# Requirement already satisfied: requests>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from sparseml) (2.31.0)
# Requirement already satisfied: scikit-image>=0.15.0 in /opt/conda/lib/python3.10/site-packages (from sparseml) (0.22.0)
# Requirement already satisfied: scikit-learn>=0.24.2 in /opt/conda/lib/python3.10/site-packages (from sparseml) (1.3.2)
# Requirement already satisfied: tqdm>=4.0.0 in /opt/conda/lib/python3.10/site-packages (from sparseml) (4.66.1)
# Requirement already satisfied: toposort>=1.0 in /opt/conda/lib/python3.10/site-packages (from sparseml) (1.10)
# Requirement already satisfied: GPUtil>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from sparseml) (1.4.0)
# Requirement already satisfied: protobuf<=3.20.3,>=3.12.2 in /opt/conda/lib/python3.10/site-packages (from sparseml) (3.20.3)
# Requirement already satisfied: click!=8.0.0,>=7.1.2 in /opt/conda/lib/python3.10/site-packages (from sparseml) (8.1.7)
# Requirement already satisfied: scipy>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from sparseml) (1.11.4)
# Requirement already satisfied: comm>=0.1.3 in /opt/conda/lib/python3.10/site-packages (from ipywidgets>=7.0.0->sparseml) (0.1.4)
# Requirement already satisfied: ipython>=6.1.0 in /opt/conda/lib/python3.10/site-packages (from ipywidgets>=7.0.0->sparseml) (8.18.1)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/conda/lib/python3.10/site-packages (from ipywidgets>=7.0.0->sparseml) (5.14.0)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in /opt/conda/lib/python3.10/site-packages (from ipywidgets>=7.0.0->sparseml) (4.0.9)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in /opt/conda/lib/python3.10/site-packages (from ipywidgets>=7.0.0->sparseml) (3.0.9)
# Requirement already satisfied: notebook in /opt/conda/lib/python3.10/site-packages (from jupyter>=1.0.0->sparseml) (6.5.6)
# Requirement already satisfied: qtconsole in /opt/conda/lib/python3.10/site-packages (from jupyter>=1.0.0->sparseml) (5.5.1)
# Requirement already satisfied: jupyter-console in /opt/conda/lib/python3.10/site-packages (from jupyter>=1.0.0->sparseml) (6.6.3)
# Requirement already satisfied: nbconvert in /opt/conda/lib/python3.10/site-packages (from jupyter>=1.0.0->sparseml) (7.12.0)
# Requirement already satisfied: ipykernel in /opt/conda/lib/python3.10/site-packages (from jupyter>=1.0.0->sparseml) (6.26.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->sparseml) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->sparseml) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->sparseml) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->sparseml) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->sparseml) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->sparseml) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->sparseml) (2.8.2)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /opt/conda/lib/python3.10/site-packages (from onnx<1.15.0,>=1.5.0->sparseml) (4.8.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.25.0->sparseml) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.25.0->sparseml) (2023.3)
# Requirement already satisfied: python-utils>=3.8.1 in /opt/conda/lib/python3.10/site-packages (from progressbar2>=3.0.0->sparseml) (3.8.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.0.0->sparseml) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.0.0->sparseml) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.0.0->sparseml) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.0.0->sparseml) (2023.11.17)
# Requirement already satisfied: networkx>=2.8 in /opt/conda/lib/python3.10/site-packages (from scikit-image>=0.15.0->sparseml) (3.2.1)
# Requirement already satisfied: imageio>=2.27 in /opt/conda/lib/python3.10/site-packages (from scikit-image>=0.15.0->sparseml) (2.33.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /opt/conda/lib/python3.10/site-packages (from scikit-image>=0.15.0->sparseml) (2023.12.9)
# Requirement already satisfied: lazy_loader>=0.3 in /opt/conda/lib/python3.10/site-packages (from scikit-image>=0.15.0->sparseml) (0.3)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.24.2->sparseml) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.24.2->sparseml) (3.2.0)
# Requirement already satisfied: py-machineid>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from sparsezoo~=1.6.0->sparseml) (0.4.6)
# Requirement already satisfied: geocoder>=1.38.0 in /opt/conda/lib/python3.10/site-packages (from sparsezoo~=1.6.0->sparseml) (1.38.1)
# Requirement already satisfied: future in /opt/conda/lib/python3.10/site-packages (from geocoder>=1.38.0->sparsezoo~=1.6.0->sparseml) (0.18.3)
# Requirement already satisfied: ratelim in /opt/conda/lib/python3.10/site-packages (from geocoder>=1.38.0->sparsezoo~=1.6.0->sparseml) (0.1.6)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from geocoder>=1.38.0->sparsezoo~=1.6.0->sparseml) (1.16.0)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->sparseml) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->sparseml) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->sparseml) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->sparseml) (3.0.41)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->sparseml) (2.17.2)
# Requirement already satisfied: stack-data in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->sparseml) (0.6.2)
# Requirement already satisfied: exceptiongroup in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->sparseml) (1.2.0)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->sparseml) (4.8.0)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/conda/lib/python3.10/site-packages (from ipykernel->jupyter>=1.0.0->sparseml) (1.8.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/conda/lib/python3.10/site-packages (from ipykernel->jupyter>=1.0.0->sparseml) (7.4.9)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/conda/lib/python3.10/site-packages (from ipykernel->jupyter>=1.0.0->sparseml) (5.5.0)
# Requirement already satisfied: nest-asyncio in /opt/conda/lib/python3.10/site-packages (from ipykernel->jupyter>=1.0.0->sparseml) (1.5.8)
# Requirement already satisfied: pyzmq>=20 in /opt/conda/lib/python3.10/site-packages (from ipykernel->jupyter>=1.0.0->sparseml) (24.0.1)
# Requirement already satisfied: tornado>=6.1 in /opt/conda/lib/python3.10/site-packages (from ipykernel->jupyter>=1.0.0->sparseml) (6.3.3)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter>=1.0.0->sparseml) (4.12.2)
# Requirement already satisfied: bleach!=5.0.0 in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter>=1.0.0->sparseml) (6.1.0)
# Requirement already satisfied: defusedxml in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter>=1.0.0->sparseml) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter>=1.0.0->sparseml) (3.1.2)
# Requirement already satisfied: jupyterlab-pygments in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter>=1.0.0->sparseml) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter>=1.0.0->sparseml) (2.1.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter>=1.0.0->sparseml) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter>=1.0.0->sparseml) (0.8.0)
# Requirement already satisfied: nbformat>=5.7 in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter>=1.0.0->sparseml) (5.9.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter>=1.0.0->sparseml) (1.5.0)
# Requirement already satisfied: tinycss2 in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter>=1.0.0->sparseml) (1.2.1)
# Requirement already satisfied: argon2-cffi in /opt/conda/lib/python3.10/site-packages (from notebook->jupyter>=1.0.0->sparseml) (23.1.0)
# Requirement already satisfied: ipython-genutils in /opt/conda/lib/python3.10/site-packages (from notebook->jupyter>=1.0.0->sparseml) (0.2.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /opt/conda/lib/python3.10/site-packages (from notebook->jupyter>=1.0.0->sparseml) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /opt/conda/lib/python3.10/site-packages (from notebook->jupyter>=1.0.0->sparseml) (0.18.0)
# Requirement already satisfied: prometheus-client in /opt/conda/lib/python3.10/site-packages (from notebook->jupyter>=1.0.0->sparseml) (0.19.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /opt/conda/lib/python3.10/site-packages (from notebook->jupyter>=1.0.0->sparseml) (1.0.0)
# Requirement already satisfied: qtpy>=2.4.0 in /opt/conda/lib/python3.10/site-packages (from qtconsole->jupyter>=1.0.0->sparseml) (2.4.1)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.10/site-packages (from bleach!=5.0.0->nbconvert->jupyter>=1.0.0->sparseml) (0.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/conda/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.0.0->sparseml) (0.8.3)
# Requirement already satisfied: entrypoints in /opt/conda/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter>=1.0.0->sparseml) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in /opt/conda/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter>=1.0.0->sparseml) (3.11.0)
# Requirement already satisfied: jupyter-server>=1.8 in /opt/conda/lib/python3.10/site-packages (from nbclassic>=0.4.7->notebook->jupyter>=1.0.0->sparseml) (2.12.1)
# Requirement already satisfied: notebook-shim>=0.2.3 in /opt/conda/lib/python3.10/site-packages (from nbclassic>=0.4.7->notebook->jupyter>=1.0.0->sparseml) (0.2.3)
# Requirement already satisfied: fastjsonschema in /opt/conda/lib/python3.10/site-packages (from nbformat>=5.7->nbconvert->jupyter>=1.0.0->sparseml) (2.19.0)
# Requirement already satisfied: jsonschema>=2.6 in /opt/conda/lib/python3.10/site-packages (from nbformat>=5.7->nbconvert->jupyter>=1.0.0->sparseml) (4.20.0)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=7.0.0->sparseml) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=7.0.0->sparseml) (0.2.12)
# Requirement already satisfied: argon2-cffi-bindings in /opt/conda/lib/python3.10/site-packages (from argon2-cffi->notebook->jupyter>=1.0.0->sparseml) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4->nbconvert->jupyter>=1.0.0->sparseml) (2.5)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->sparseml) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->sparseml) (2.4.1)
# Requirement already satisfied: pure-eval in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->sparseml) (0.2.2)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter>=1.0.0->sparseml) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter>=1.0.0->sparseml) (2023.11.2)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter>=1.0.0->sparseml) (0.32.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter>=1.0.0->sparseml) (0.13.2)
# Requirement already satisfied: anyio>=3.1.0 in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0.0->sparseml) (3.7.1)
# Requirement already satisfied: jupyter-events>=0.9.0 in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0.0->sparseml) (0.9.0)
# Requirement already satisfied: jupyter-server-terminals in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0.0->sparseml) (0.4.4)
# Requirement already satisfied: overrides in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0.0->sparseml) (7.4.0)
# Requirement already satisfied: websocket-client in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0.0->sparseml) (1.7.0)
# Requirement already satisfied: cffi>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter>=1.0.0->sparseml) (1.16.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0.0->sparseml) (1.3.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter>=1.0.0->sparseml) (2.21)
# Requirement already satisfied: python-json-logger>=2.0.4 in /opt/conda/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0.0->sparseml) (2.0.7)
# Requirement already satisfied: rfc3339-validator in /opt/conda/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0.0->sparseml) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0.0->sparseml) (0.1.1)
# Requirement already satisfied: fqdn in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0.0->sparseml) (1.5.1)
# Requirement already satisfied: isoduration in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0.0->sparseml) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0.0->sparseml) (2.4)
# Requirement already satisfied: uri-template in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0.0->sparseml) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0.0->sparseml) (1.13)
# Requirement already satisfied: arrow>=0.15.0 in /opt/conda/lib/python3.10/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0.0->sparseml) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /opt/conda/lib/python3.10/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0.0->sparseml) (2.8.19.14)
# Using cached sparseml-1.6.1-py3-none-any.whl (1.1 MB)
# Installing collected packages: sparseml
# Successfully installed sparseml-1.6.1
# Requirement already satisfied: sparseml[transformers] in /opt/conda/lib/python3.10/site-packages (1.6.1)
# Requirement already satisfied: sparsezoo~=1.6.0 in /opt/conda/lib/python3.10/site-packages (from sparseml[transformers]) (1.6.1)
# Requirement already satisfied: setuptools<=59.5.0 in /opt/conda/lib/python3.10/site-packages (from sparseml[transformers]) (59.5.0)
# Requirement already satisfied: jupyter>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from sparseml[transformers]) (1.0.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in /opt/conda/lib/python3.10/site-packages (from sparseml[transformers]) (8.1.1)
# Requirement already satisfied: pyyaml>=5.0.0 in /opt/conda/lib/python3.10/site-packages (from sparseml[transformers]) (6.0.1)
# Requirement already satisfied: progressbar2>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from sparseml[transformers]) (4.3.2)
# Requirement already satisfied: numpy>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from sparseml[transformers]) (1.25.2)
# Requirement already satisfied: matplotlib>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from sparseml[transformers]) (3.7.3)
# Requirement already satisfied: merge-args>=0.1.0 in /opt/conda/lib/python3.10/site-packages (from sparseml[transformers]) (0.1.5)
# Requirement already satisfied: onnx<1.15.0,>=1.5.0 in /opt/conda/lib/python3.10/site-packages (from sparseml[transformers]) (1.14.1)
# Requirement already satisfied: pandas>=0.25.0 in /opt/conda/lib/python3.10/site-packages (from sparseml[transformers]) (2.0.3)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from sparseml[transformers]) (23.2)
# Requirement already satisfied: psutil>=5.0.0 in /opt/conda/lib/python3.10/site-packages (from sparseml[transformers]) (5.9.3)
# Requirement already satisfied: pydantic<2.0.0,>=1.8.2 in /opt/conda/lib/python3.10/site-packages (from sparseml[transformers]) (1.10.13)
# Requirement already satisfied: requests>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from sparseml[transformers]) (2.31.0)
# Requirement already satisfied: scikit-image>=0.15.0 in /opt/conda/lib/python3.10/site-packages (from sparseml[transformers]) (0.22.0)
# Requirement already satisfied: scikit-learn>=0.24.2 in /opt/conda/lib/python3.10/site-packages (from sparseml[transformers]) (1.3.2)
# Requirement already satisfied: tqdm>=4.0.0 in /opt/conda/lib/python3.10/site-packages (from sparseml[transformers]) (4.66.1)
# Requirement already satisfied: toposort>=1.0 in /opt/conda/lib/python3.10/site-packages (from sparseml[transformers]) (1.10)
# Requirement already satisfied: GPUtil>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from sparseml[transformers]) (1.4.0)
# Requirement already satisfied: protobuf<=3.20.3,>=3.12.2 in /opt/conda/lib/python3.10/site-packages (from sparseml[transformers]) (3.20.3)
# Requirement already satisfied: click!=8.0.0,>=7.1.2 in /opt/conda/lib/python3.10/site-packages (from sparseml[transformers]) (8.1.7)
# Requirement already satisfied: scipy>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from sparseml[transformers]) (1.11.4)
# Requirement already satisfied: torch<2.2,>=1.7.0 in /opt/conda/lib/python3.10/site-packages (from sparseml[transformers]) (2.0.1)
# Requirement already satisfied: gputils in /opt/conda/lib/python3.10/site-packages (from sparseml[transformers]) (1.0.6)
# Requirement already satisfied: nm-transformers~=1.6.0 in /opt/conda/lib/python3.10/site-packages (from sparseml[transformers]) (1.6.0.43401)
# Requirement already satisfied: datasets<=2.14.6 in /opt/conda/lib/python3.10/site-packages (from sparseml[transformers]) (2.14.6)
# Requirement already satisfied: seqeval in /opt/conda/lib/python3.10/site-packages (from sparseml[transformers]) (1.2.2)
# Requirement already satisfied: einops in /opt/conda/lib/python3.10/site-packages (from sparseml[transformers]) (0.7.0)
# Requirement already satisfied: accelerate>=0.20.3 in /opt/conda/lib/python3.10/site-packages (from sparseml[transformers]) (0.26.1)
# Collecting huggingface-hub (from accelerate>=0.20.3->sparseml[transformers])
#   Using cached huggingface_hub-0.20.2-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/conda/lib/python3.10/site-packages (from accelerate>=0.20.3->sparseml[transformers]) (0.4.1)
# Requirement already satisfied: pyarrow>=8.0.0 in /opt/conda/lib/python3.10/site-packages (from datasets<=2.14.6->sparseml[transformers]) (14.0.1)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from datasets<=2.14.6->sparseml[transformers]) (0.3.7)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.10/site-packages (from datasets<=2.14.6->sparseml[transformers]) (3.4.1)
# Requirement already satisfied: multiprocess in /opt/conda/lib/python3.10/site-packages (from datasets<=2.14.6->sparseml[transformers]) (0.70.15)
# Requirement already satisfied: fsspec<=2023.10.0,>=2023.1.0 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]<=2023.10.0,>=2023.1.0->datasets<=2.14.6->sparseml[transformers]) (2023.10.0)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from datasets<=2.14.6->sparseml[transformers]) (3.9.1)
# Requirement already satisfied: comm>=0.1.3 in /opt/conda/lib/python3.10/site-packages (from ipywidgets>=7.0.0->sparseml[transformers]) (0.1.4)
# Requirement already satisfied: ipython>=6.1.0 in /opt/conda/lib/python3.10/site-packages (from ipywidgets>=7.0.0->sparseml[transformers]) (8.18.1)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/conda/lib/python3.10/site-packages (from ipywidgets>=7.0.0->sparseml[transformers]) (5.14.0)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in /opt/conda/lib/python3.10/site-packages (from ipywidgets>=7.0.0->sparseml[transformers]) (4.0.9)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in /opt/conda/lib/python3.10/site-packages (from ipywidgets>=7.0.0->sparseml[transformers]) (3.0.9)
# Requirement already satisfied: notebook in /opt/conda/lib/python3.10/site-packages (from jupyter>=1.0.0->sparseml[transformers]) (6.5.6)
# Requirement already satisfied: qtconsole in /opt/conda/lib/python3.10/site-packages (from jupyter>=1.0.0->sparseml[transformers]) (5.5.1)
# Requirement already satisfied: jupyter-console in /opt/conda/lib/python3.10/site-packages (from jupyter>=1.0.0->sparseml[transformers]) (6.6.3)
# Requirement already satisfied: nbconvert in /opt/conda/lib/python3.10/site-packages (from jupyter>=1.0.0->sparseml[transformers]) (7.12.0)
# Requirement already satisfied: ipykernel in /opt/conda/lib/python3.10/site-packages (from jupyter>=1.0.0->sparseml[transformers]) (6.26.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->sparseml[transformers]) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->sparseml[transformers]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->sparseml[transformers]) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->sparseml[transformers]) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->sparseml[transformers]) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->sparseml[transformers]) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->sparseml[transformers]) (2.8.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from nm-transformers~=1.6.0->sparseml[transformers]) (3.13.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from nm-transformers~=1.6.0->sparseml[transformers]) (2023.12.25)
# Requirement already satisfied: tokenizers<0.15,>=0.14 in /opt/conda/lib/python3.10/site-packages (from nm-transformers~=1.6.0->sparseml[transformers]) (0.14.1)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /opt/conda/lib/python3.10/site-packages (from onnx<1.15.0,>=1.5.0->sparseml[transformers]) (4.8.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.25.0->sparseml[transformers]) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.25.0->sparseml[transformers]) (2023.3)
# Requirement already satisfied: python-utils>=3.8.1 in /opt/conda/lib/python3.10/site-packages (from progressbar2>=3.0.0->sparseml[transformers]) (3.8.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.0.0->sparseml[transformers]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.0.0->sparseml[transformers]) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.0.0->sparseml[transformers]) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.0.0->sparseml[transformers]) (2023.11.17)
# Requirement already satisfied: networkx>=2.8 in /opt/conda/lib/python3.10/site-packages (from scikit-image>=0.15.0->sparseml[transformers]) (3.2.1)
# Requirement already satisfied: imageio>=2.27 in /opt/conda/lib/python3.10/site-packages (from scikit-image>=0.15.0->sparseml[transformers]) (2.33.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /opt/conda/lib/python3.10/site-packages (from scikit-image>=0.15.0->sparseml[transformers]) (2023.12.9)
# Requirement already satisfied: lazy_loader>=0.3 in /opt/conda/lib/python3.10/site-packages (from scikit-image>=0.15.0->sparseml[transformers]) (0.3)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.24.2->sparseml[transformers]) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.24.2->sparseml[transformers]) (3.2.0)
# Requirement already satisfied: py-machineid>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from sparsezoo~=1.6.0->sparseml[transformers]) (0.4.6)
# Requirement already satisfied: geocoder>=1.38.0 in /opt/conda/lib/python3.10/site-packages (from sparsezoo~=1.6.0->sparseml[transformers]) (1.38.1)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch<2.2,>=1.7.0->sparseml[transformers]) (1.12)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch<2.2,>=1.7.0->sparseml[transformers]) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /opt/conda/lib/python3.10/site-packages (from torch<2.2,>=1.7.0->sparseml[transformers]) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /opt/conda/lib/python3.10/site-packages (from torch<2.2,>=1.7.0->sparseml[transformers]) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /opt/conda/lib/python3.10/site-packages (from torch<2.2,>=1.7.0->sparseml[transformers]) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /opt/conda/lib/python3.10/site-packages (from torch<2.2,>=1.7.0->sparseml[transformers]) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /opt/conda/lib/python3.10/site-packages (from torch<2.2,>=1.7.0->sparseml[transformers]) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /opt/conda/lib/python3.10/site-packages (from torch<2.2,>=1.7.0->sparseml[transformers]) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /opt/conda/lib/python3.10/site-packages (from torch<2.2,>=1.7.0->sparseml[transformers]) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /opt/conda/lib/python3.10/site-packages (from torch<2.2,>=1.7.0->sparseml[transformers]) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /opt/conda/lib/python3.10/site-packages (from torch<2.2,>=1.7.0->sparseml[transformers]) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /opt/conda/lib/python3.10/site-packages (from torch<2.2,>=1.7.0->sparseml[transformers]) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /opt/conda/lib/python3.10/site-packages (from torch<2.2,>=1.7.0->sparseml[transformers]) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /opt/conda/lib/python3.10/site-packages (from torch<2.2,>=1.7.0->sparseml[transformers]) (2.0.0)
# Requirement already satisfied: wheel in /opt/conda/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch<2.2,>=1.7.0->sparseml[transformers]) (0.42.0)
# Requirement already satisfied: cmake in /opt/conda/lib/python3.10/site-packages (from triton==2.0.0->torch<2.2,>=1.7.0->sparseml[transformers]) (3.28.1)
# Requirement already satisfied: lit in /opt/conda/lib/python3.10/site-packages (from triton==2.0.0->torch<2.2,>=1.7.0->sparseml[transformers]) (17.0.6)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets<=2.14.6->sparseml[transformers]) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets<=2.14.6->sparseml[transformers]) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets<=2.14.6->sparseml[transformers]) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets<=2.14.6->sparseml[transformers]) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets<=2.14.6->sparseml[transformers]) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets<=2.14.6->sparseml[transformers]) (4.0.3)
# Requirement already satisfied: future in /opt/conda/lib/python3.10/site-packages (from geocoder>=1.38.0->sparsezoo~=1.6.0->sparseml[transformers]) (0.18.3)
# Requirement already satisfied: ratelim in /opt/conda/lib/python3.10/site-packages (from geocoder>=1.38.0->sparsezoo~=1.6.0->sparseml[transformers]) (0.1.6)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from geocoder>=1.38.0->sparsezoo~=1.6.0->sparseml[transformers]) (1.16.0)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->sparseml[transformers]) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->sparseml[transformers]) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->sparseml[transformers]) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->sparseml[transformers]) (3.0.41)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->sparseml[transformers]) (2.17.2)
# Requirement already satisfied: stack-data in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->sparseml[transformers]) (0.6.2)
# Requirement already satisfied: exceptiongroup in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->sparseml[transformers]) (1.2.0)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->sparseml[transformers]) (4.8.0)
#   Using cached huggingface_hub-0.17.3-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/conda/lib/python3.10/site-packages (from ipykernel->jupyter>=1.0.0->sparseml[transformers]) (1.8.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/conda/lib/python3.10/site-packages (from ipykernel->jupyter>=1.0.0->sparseml[transformers]) (7.4.9)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/conda/lib/python3.10/site-packages (from ipykernel->jupyter>=1.0.0->sparseml[transformers]) (5.5.0)
# Requirement already satisfied: nest-asyncio in /opt/conda/lib/python3.10/site-packages (from ipykernel->jupyter>=1.0.0->sparseml[transformers]) (1.5.8)
# Requirement already satisfied: pyzmq>=20 in /opt/conda/lib/python3.10/site-packages (from ipykernel->jupyter>=1.0.0->sparseml[transformers]) (24.0.1)
# Requirement already satisfied: tornado>=6.1 in /opt/conda/lib/python3.10/site-packages (from ipykernel->jupyter>=1.0.0->sparseml[transformers]) (6.3.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch<2.2,>=1.7.0->sparseml[transformers]) (2.1.3)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter>=1.0.0->sparseml[transformers]) (4.12.2)
# Requirement already satisfied: bleach!=5.0.0 in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter>=1.0.0->sparseml[transformers]) (6.1.0)
# Requirement already satisfied: defusedxml in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter>=1.0.0->sparseml[transformers]) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter>=1.0.0->sparseml[transformers]) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter>=1.0.0->sparseml[transformers]) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter>=1.0.0->sparseml[transformers]) (0.8.0)
# Requirement already satisfied: nbformat>=5.7 in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter>=1.0.0->sparseml[transformers]) (5.9.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter>=1.0.0->sparseml[transformers]) (1.5.0)
# Requirement already satisfied: tinycss2 in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter>=1.0.0->sparseml[transformers]) (1.2.1)
# Requirement already satisfied: argon2-cffi in /opt/conda/lib/python3.10/site-packages (from notebook->jupyter>=1.0.0->sparseml[transformers]) (23.1.0)
# Requirement already satisfied: ipython-genutils in /opt/conda/lib/python3.10/site-packages (from notebook->jupyter>=1.0.0->sparseml[transformers]) (0.2.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /opt/conda/lib/python3.10/site-packages (from notebook->jupyter>=1.0.0->sparseml[transformers]) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /opt/conda/lib/python3.10/site-packages (from notebook->jupyter>=1.0.0->sparseml[transformers]) (0.18.0)
# Requirement already satisfied: prometheus-client in /opt/conda/lib/python3.10/site-packages (from notebook->jupyter>=1.0.0->sparseml[transformers]) (0.19.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /opt/conda/lib/python3.10/site-packages (from notebook->jupyter>=1.0.0->sparseml[transformers]) (1.0.0)
# Requirement already satisfied: qtpy>=2.4.0 in /opt/conda/lib/python3.10/site-packages (from qtconsole->jupyter>=1.0.0->sparseml[transformers]) (2.4.1)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch<2.2,>=1.7.0->sparseml[transformers]) (1.3.0)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.10/site-packages (from bleach!=5.0.0->nbconvert->jupyter>=1.0.0->sparseml[transformers]) (0.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/conda/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.0.0->sparseml[transformers]) (0.8.3)
# Requirement already satisfied: entrypoints in /opt/conda/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter>=1.0.0->sparseml[transformers]) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in /opt/conda/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter>=1.0.0->sparseml[transformers]) (3.11.0)
# Requirement already satisfied: jupyter-server>=1.8 in /opt/conda/lib/python3.10/site-packages (from nbclassic>=0.4.7->notebook->jupyter>=1.0.0->sparseml[transformers]) (2.12.1)
# Requirement already satisfied: notebook-shim>=0.2.3 in /opt/conda/lib/python3.10/site-packages (from nbclassic>=0.4.7->notebook->jupyter>=1.0.0->sparseml[transformers]) (0.2.3)
# Requirement already satisfied: fastjsonschema in /opt/conda/lib/python3.10/site-packages (from nbformat>=5.7->nbconvert->jupyter>=1.0.0->sparseml[transformers]) (2.19.0)
# Requirement already satisfied: jsonschema>=2.6 in /opt/conda/lib/python3.10/site-packages (from nbformat>=5.7->nbconvert->jupyter>=1.0.0->sparseml[transformers]) (4.20.0)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=7.0.0->sparseml[transformers]) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=7.0.0->sparseml[transformers]) (0.2.12)
# Requirement already satisfied: argon2-cffi-bindings in /opt/conda/lib/python3.10/site-packages (from argon2-cffi->notebook->jupyter>=1.0.0->sparseml[transformers]) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4->nbconvert->jupyter>=1.0.0->sparseml[transformers]) (2.5)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->sparseml[transformers]) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->sparseml[transformers]) (2.4.1)
# Requirement already satisfied: pure-eval in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->sparseml[transformers]) (0.2.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter>=1.0.0->sparseml[transformers]) (2023.11.2)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter>=1.0.0->sparseml[transformers]) (0.32.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter>=1.0.0->sparseml[transformers]) (0.13.2)
# Requirement already satisfied: anyio>=3.1.0 in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0.0->sparseml[transformers]) (3.7.1)
# Requirement already satisfied: jupyter-events>=0.9.0 in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0.0->sparseml[transformers]) (0.9.0)
# Requirement already satisfied: jupyter-server-terminals in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0.0->sparseml[transformers]) (0.4.4)
# Requirement already satisfied: overrides in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0.0->sparseml[transformers]) (7.4.0)
# Requirement already satisfied: websocket-client in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0.0->sparseml[transformers]) (1.7.0)
# Requirement already satisfied: cffi>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter>=1.0.0->sparseml[transformers]) (1.16.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0.0->sparseml[transformers]) (1.3.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter>=1.0.0->sparseml[transformers]) (2.21)
# Requirement already satisfied: python-json-logger>=2.0.4 in /opt/conda/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0.0->sparseml[transformers]) (2.0.7)
# Requirement already satisfied: rfc3339-validator in /opt/conda/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0.0->sparseml[transformers]) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0.0->sparseml[transformers]) (0.1.1)
# Requirement already satisfied: fqdn in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0.0->sparseml[transformers]) (1.5.1)
# Requirement already satisfied: isoduration in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0.0->sparseml[transformers]) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0.0->sparseml[transformers]) (2.4)
# Requirement already satisfied: uri-template in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0.0->sparseml[transformers]) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0.0->sparseml[transformers]) (1.13)
# Requirement already satisfied: arrow>=0.15.0 in /opt/conda/lib/python3.10/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0.0->sparseml[transformers]) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /opt/conda/lib/python3.10/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0.0->sparseml[transformers]) (2.8.19.14)
# Using cached huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
# Installing collected packages: huggingface-hub
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# transformers 4.36.2 requires huggingface-hub<1.0,>=0.19.3, but you have huggingface-hub 0.17.3 which is incompatible.
# Successfully installed huggingface-hub-0.17.3

# %%
# !sparseml.transformers.text_classification -h
# Out:
# Traceback (most recent call last):
#   File "/opt/conda/bin/sparseml.transformers.text_classification", line 5, in <module>
#     from sparseml.transformers.text_classification import main
#   File "/opt/conda/lib/python3.10/site-packages/sparseml/transformers/__init__.py", line 28, in <module>
#     import transformers as _transformers
#   File "/opt/conda/lib/python3.10/site-packages/transformers/__init__.py", line 26, in <module>
#     from . import dependency_versions_check
#   File "/opt/conda/lib/python3.10/site-packages/transformers/dependency_versions_check.py", line 16, in <module>
#     from .utils.versions import require_version, require_version_core
#   File "/opt/conda/lib/python3.10/site-packages/transformers/utils/__init__.py", line 61, in <module>
#     from .hub import (
#   File "/opt/conda/lib/python3.10/site-packages/transformers/utils/hub.py", line 94, in <module>
#     PYTORCH_PRETRAINED_BERT_CACHE = os.getenv("PYTORCH_PRETRAINED_BERT_CACHE", constants.HF_HUB_CACHE)
# AttributeError: module 'huggingface_hub.constants' has no attribute 'HF_HUB_CACHE'
